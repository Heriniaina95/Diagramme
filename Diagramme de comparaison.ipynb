# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/DELL/DATA SET/StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#Elaboration cahier de charge
#titre,objectif et but(),contexte(introduction-probleme-solution),travail demande
#collecte de donnees,cleaning data,visualisation ou analyse,creation ML,test et deployment,delais,personnels responsable
#Jointplot() elle va ajoute des histogrammes a cahque variable
sns.jointplot(x="math score",y="reading score",data=df)

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
#kind= ajustement lineaire
sns.jointplot(x="math score",y="reading score",data=df,kind="reg")

# %%
#countplot=variable quantitative
sns.countplot(x="gender",data=df)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.countplot(y="parental level of education",data=df)
# Out:
# <Axes: xlabel='count', ylabel='parental level of education'>

# %%
#bartplot=porcentage de proportion
sns.barplot(x="gender",y="reading score",data=df)
# Out:
# <Axes: xlabel='gender', ylabel='reading score'>

# %%
#pairplot=visialusation par pair"
sns.pairplot(data=df,hue="gender",palette="viridis",corner="true")
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#pairplot=visialusation par pair"
sns.pairplot(data=df,hue="gender",palette="viridis",diag_kind="hist")
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
